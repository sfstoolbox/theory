% %%
addpath('~/git/sfs');
SFS_start;

% %%
clear all;

%% ===== Configuration ===================================================
X = [-2 2];
Y = [-2 2];
Z = 0;
xs = [1 1 0];
f = 800;

%% ===== Toolbox settings ================================================
conf = SFS_config;
conf.resolution = 1000;
conf.xref = [0 1 0];

%% ===== Main ============================================================
sound_field_mono_plane_wave(X,Y,Z,xs,f,conf);
